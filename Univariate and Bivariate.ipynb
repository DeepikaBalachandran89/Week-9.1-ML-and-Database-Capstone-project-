# %%
import pandas as pd

# %%
dataset=pd.read_csv('diabetes.csv')

# %%
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
dataset["Glucose"].mean()
# Out:
# 120.89453125

# %%
dataset["Glucose"].median()
# Out:
# 117.0

# %%
dataset["Glucose"].mode()[0]
# Out:
# 99

# %% [markdown]
# ##QUAN

# %%
if(dataset["Pregnancies"].dtype=='O'):
    print("qual")
else:
    print("quan")
# Out:
# quan

# %%
quan=[]
qual=[]
for columnName in dataset.columns:
    #print(columnName)
    if(dataset[columnName].dtype=='O'):
        #print("qual")
        qual.append(columnName)
    else:
        #print("quan")
        quan.append(columnName)

# %%
quan
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %% [markdown]
# ##CENTRAL TENDENCY

# %%
descriptive=pd.DataFrame()

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)

# %%
descriptive
# Out:
#        Pregnancies Glucose BloodPressure SkinThickness Insulin  BMI  \
# Mean           NaN     NaN           NaN           NaN     NaN  NaN
# Median         NaN     NaN           NaN           NaN     NaN  NaN
# Mode           NaN     NaN           NaN           NaN     NaN  NaN
#
#        DiabetesPedigreeFunction  Age Outcome
# Mean                        NaN  NaN     NaN
# Median                      NaN  NaN     NaN
# Mode                        NaN  NaN     NaN

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12680\1222842922.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["Mean"]=dataset[columnName].mean()

# %%
descriptive
# Out:
#        Pregnancies     Glucose BloodPressure SkinThickness    Insulin  \
# Mean      3.845052  120.894531     69.105469     20.536458  79.799479
# Median         NaN         NaN           NaN           NaN        NaN
# Mode           NaN         NaN           NaN           NaN        NaN
#
#               BMI DiabetesPedigreeFunction        Age   Outcome
# Mean    31.992578                 0.471876  33.240885  0.348958
# Median        NaN                      NaN        NaN       NaN
# Mode          NaN                      NaN        NaN       NaN

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12680\1390373511.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["Mean"]=dataset[columnName].mean()
# ...

# %%
descriptive
# Out:
#        Pregnancies     Glucose BloodPressure SkinThickness    Insulin  \
# Mean      3.845052  120.894531     69.105469     20.536458  79.799479
# Median         3.0       117.0          72.0          23.0       30.5
# Mode             1          99            70             0          0
#
#               BMI DiabetesPedigreeFunction        Age   Outcome
# Mean    31.992578                 0.471876  33.240885  0.348958
# Median       32.0                   0.3725       29.0       0.0
# Mode         32.0                    0.254         22         0

# %% [markdown]
# ##PERCENTILE

# %%
import numpy as np

# %%
np.percentile(dataset["BloodPressure"],100)
# Out:
# 122.0

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%",
                               "Q3:75%","99%","Q4:100%"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12680\61818029.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["Mean"]=dataset[columnName].mean()
# ...

# %%
descriptive
# Out:
#         Pregnancies     Glucose BloodPressure SkinThickness    Insulin  \
# Mean       3.845052  120.894531     69.105469     20.536458  79.799479
# Median          3.0       117.0          72.0          23.0       30.5
# Mode              1          99            70             0          0
# Q1:25%          1.0        99.0          62.0           0.0        0.0
# Q2:50%          3.0       117.0          72.0          23.0       30.5
# Q3:75%          6.0      140.25          80.0          32.0     127.25
# 99%            13.0       196.0         106.0         51.33      519.9
# Q4:100%        17.0       199.0         122.0          99.0      846.0
#
#                BMI DiabetesPedigreeFunction        Age   Outcome
# Mean     31.992578                 0.471876  33.240885  0.348958
# Median        32.0                   0.3725       29.0       0.0
# Mode          32.0                    0.254         22         0
# Q1:25%        27.3                  0.24375       24.0       0.0
# ...

# %% [markdown]
# ###FINDING OUTILIERS

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%",
                               "Q3:75%","99%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
    descriptive[columnName]["Lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
    descriptive[columnName]["Greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
    descriptive[columnName]["Min"]=dataset[columnName].min()
    descriptive[columnName]["Max"]=dataset[columnName].max()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12680\3467927199.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["Mean"]=dataset[columnName].mean()
# ...

# %%
descriptive
# Out:
#         Pregnancies     Glucose BloodPressure SkinThickness    Insulin  \
# Mean       3.845052  120.894531     69.105469     20.536458  79.799479
# Median          3.0       117.0          72.0          23.0       30.5
# Mode              1          99            70             0          0
# Q1:25%          1.0        99.0          62.0           0.0        0.0
# Q2:50%          3.0       117.0          72.0          23.0       30.5
# Q3:75%          6.0      140.25          80.0          32.0     127.25
# 99%            13.0       196.0         106.0         51.33      519.9
# Q4:100%        17.0       199.0         122.0          99.0      846.0
# IQR             5.0       41.25          18.0          32.0     127.25
# 1.5rule         7.5      61.875          27.0          48.0    190.875
# Lesser         -6.5      37.125          35.0         -48.0   -190.875
# Greater        13.5     202.125         107.0          80.0    318.125
# ...

# %%
lesser=[]
greater=[]

for columnName in quan:
    if(descriptive[columnName]["Lesser"]>descriptive[columnName]["Min"]):
        lesser.append(columnName)
    if(descriptive[columnName]["Greater"]<descriptive[columnName]["Q4:100%"]):
        greater.append(columnName)

# %%
lesser
# Out:
# ['Glucose', 'BloodPressure', 'BMI']

# %%
greater
# Out:
# ['Pregnancies',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %% [markdown]
# ##REPLACING OUTLIERS

# %%
for column in lesser:
    dataset[column][dataset[column]<descriptive[column]["Lesser"]]=descriptive[column]["Lesser"]
for column in greater:
    dataset[column][dataset[column]>descriptive[column]["Greater"]]=descriptive[column]["Greater"]
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12680\3400726572.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataset[column][dataset[column]<descriptive[column]["Lesser"]]=descriptive[column]["Lesser"]
# ...

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%",
                               "Q3:75%","99%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
    descriptive[columnName]["Lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
    descriptive[columnName]["Greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
    descriptive[columnName]["Min"]=dataset[columnName].min()
    descriptive[columnName]["Max"]=dataset[columnName].max()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12680\3467927199.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["Mean"]=dataset[columnName].mean()
# ...

# %%
descriptive
# Out:
#         Pregnancies    Glucose BloodPressure SkinThickness    Insulin  \
# Mean        3.83724  121.13623     70.684896     20.511719  73.652669
# Median          3.0      117.0          72.0          23.0       30.5
# Mode            1.0       99.0            70             0        0.0
# Q1:25%          1.0       99.0          62.0           0.0        0.0
# Q2:50%          3.0      117.0          72.0          23.0       30.5
# Q3:75%          6.0     140.25          80.0          32.0     127.25
# 99%            13.0      196.0         106.0         51.33    318.125
# Q4:100%        13.5      199.0         107.0          80.0    318.125
# IQR             5.0      41.25          18.0          32.0     127.25
# 1.5rule         7.5     61.875          27.0          48.0    190.875
# Lesser         -6.5     37.125          35.0         -48.0   -190.875
# Greater        13.5    202.125         107.0          80.0    318.125
# ...

# %%
lesser=[]
greater=[]

for columnName in quan:
    if(descriptive[columnName]["Lesser"]>descriptive[columnName]["Min"]):
        lesser.append(columnName)
    if(descriptive[columnName]["Greater"]<descriptive[columnName]["Q4:100%"]):
        greater.append(columnName)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# []

# %% [markdown]
# ##QUESTIONS

# %% [markdown]
# #1. Count of Pregnancies who Have Diabetes

# %%
diabetes_dataset = dataset[dataset['Outcome'] == 1]

# %%
diabetes_dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0             72             35    0.000  33.6
# 2            8.0    183.0             64              0    0.000  23.3
# 4            0.0    137.0             40             35  168.000  43.1
# 6            3.0     78.0             50             32   88.000  31.0
# 8            2.0    197.0             70             45  318.125  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755          1.0    128.0             88             39  110.000  36.5
# 757          0.0    123.0             72              0    0.000  36.3
# 759          6.0    190.0             92              0    0.000  35.5
# 761          9.0    170.0             74             31    0.000  44.0
# 766          1.0    126.0             60              0    0.000  30.1
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0        1
# ...

# %%
pregnancies_diabetic = diabetes_dataset['Pregnancies'].count()

# %%
pregnancies_diabetic
# Out:
# 268

# %%
dataset.head(50)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0           6.0    148.0             72             35    0.000  33.60
# 1           1.0     85.0             66             29    0.000  26.60
# 2           8.0    183.0             64              0    0.000  23.30
# 3           1.0     89.0             66             23   94.000  28.10
# 4           0.0    137.0             40             35  168.000  43.10
# 5           5.0    116.0             74              0    0.000  25.60
# 6           3.0     78.0             50             32   88.000  31.00
# 7          10.0    115.0             35              0    0.000  35.30
# 8           2.0    197.0             70             45  318.125  30.50
# 9           8.0    125.0             96              0    0.000  13.35
# 10          4.0    110.0             92              0    0.000  37.60
# 11         10.0    168.0             74              0    0.000  38.00
# ...

# %% [markdown]
# ##2.Above Age 50 Pregnancies ,How many members having Diabetes count?

# %%
dataset_diabetic=dataset[(dataset['Age']>50)&(dataset['Outcome']==1)]

# %%
dataset_diabetic
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 8            2.0    197.0             70             45  318.125  30.50
# 9            8.0    125.0             96              0    0.000  13.35
# 13           1.0    189.0             60             23  318.125  30.10
# 14           5.0    166.0             72             19  175.000  25.80
# 24          11.0    143.0             94             33  146.000  36.60
# 39           4.0    111.0             72             47  207.000  37.10
# 43           9.0    171.0            107             24  240.000  45.40
# 53           8.0    176.0             90             34  300.000  33.70
# 93           4.0    134.0             72              0    0.000  23.80
# 115          4.0    146.0             92              0    0.000  31.20
# 129          0.0    105.0             84              0    0.000  27.90
# 186          8.0    181.0             68             36  318.125  30.10
# ...

# %%
above50_diabetic = dataset_diabetic['Pregnancies'].count()

# %%
above50_diabetic
# Out:
# 38

# %% [markdown]
# ##3. Diabetes Who Have not Pregnancy?

# %%
diabetes_with=dataset[(dataset['Pregnancies']==0) & (dataset['Outcome'] == 1)]

# %%
diabetes_with
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 4            0.0    137.0             40             35  168.000  43.10
# 16           0.0    118.0             84             47  230.000  45.80
# 45           0.0    180.0             66             39    0.000  42.00
# 66           0.0    109.0             88             30    0.000  32.50
# 78           0.0    131.0             35              0    0.000  43.20
# 109          0.0     95.0             85             25   36.000  37.40
# 120          0.0    162.0             76             56  100.000  50.55
# 124          0.0    113.0             76              0    0.000  33.30
# 129          0.0    105.0             84              0    0.000  27.90
# 164          0.0    131.0             88              0    0.000  31.60
# 177          0.0    129.0            107             46  130.000  50.55
# 213          0.0    140.0             65             26  130.000  42.60
# ...

# %%
zero_preg=diabetes_with['Pregnancies'].count()

# %%
zero_preg
# Out:
# 38

# %% [markdown]
# ##4.Density Of Age limit of Diabetes

# %%
import seaborn as sns

# %%
sns.distplot(dataset["Age"])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12680\1741011122.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ##5.Age Distibution of count using Histogram

# %%
import matplotlib.pyplot as plt
plt.hist(dataset['Age'], bins=30, edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##6.Total Count of Pregnancy Distribution

# %%
counts = dataset['Pregnancies'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(counts, labels=counts.index, autopct='%1.1f%%')
plt.title('Pregnancy Count Distribution')
plt.show()

# %%
counts = dataset['Pregnancies'].value_counts()

# %%
counts
# Out:
# Pregnancies
# 1.0     135
# 0.0     111
# 2.0     103
# 3.0      75
# 4.0      68
# 5.0      57
# 6.0      50
# 7.0      45
# 8.0      38
# 9.0      28
# 10.0     24
# 11.0     11
# 13.0     10
# 12.0      9
# 13.5      4
# Name: count, dtype: int64

# %%
counts = dataset['Outcome'].value_counts()

# %%
counts
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
one_pregnancy_df = dataset[dataset['Pregnancies'] == 1]

# %%
one_pregnancy_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1            1.0     85.0             66             29    0.000  26.6
# 3            1.0     89.0             66             23   94.000  28.1
# 13           1.0    189.0             60             23  318.125  30.1
# 18           1.0    103.0             35             38   83.000  43.3
# 19           1.0    115.0             70             30   96.000  34.6
# ..           ...      ...            ...            ...      ...   ...
# 751          1.0    121.0             78             39   74.000  39.0
# 755          1.0    128.0             88             39  110.000  36.5
# 758          1.0    106.0             76              0    0.000  37.5
# 766          1.0    126.0             60              0    0.000  30.1
# 767          1.0     93.0             70             31    0.000  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 1                       0.351  31.0        0
# ...

# %%
one_pregnancy_df.head(60)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 1            1.0   85.000             66             29    0.000  26.60
# 3            1.0   89.000             66             23   94.000  28.10
# 13           1.0  189.000             60             23  318.125  30.10
# 18           1.0  103.000             35             38   83.000  43.30
# 19           1.0  115.000             70             30   96.000  34.60
# 27           1.0   97.000             66             15  140.000  23.20
# 46           1.0  146.000             56              0    0.000  29.70
# 50           1.0  103.000             80             11   82.000  19.40
# 51           1.0  101.000             50             15   36.000  24.20
# 55           1.0   73.000             50             10    0.000  23.00
# 68           1.0   95.000             66             13   38.000  19.60
# 74           1.0   79.000             75             30    0.000  32.00
# ...

# %% [markdown]
# ##7. Display of Data to understand the Histogram

# %%
dataset.hist(bins=50, figsize=(20,15)) 
plt.show()

# %%
dataset.tail(60)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 708          9.0    164.0             78              0    0.000  32.8
# 709          2.0     93.0             64             32  160.000  38.0
# 710          3.0    158.0             64             13  318.125  31.2
# 711          5.0    126.0             78             27   22.000  29.6
# 712         10.0    129.0             62             36    0.000  41.2
# 713          0.0    134.0             58             20  291.000  26.4
# 714          3.0    102.0             74              0    0.000  29.5
# 715          7.0    187.0             50             33  318.125  33.9
# 716          3.0    173.0             78             39  185.000  33.8
# 717         10.0     94.0             72             18    0.000  23.1
# 718          1.0    108.0             60             46  178.000  35.5
# 719          5.0     97.0             76             27    0.000  35.6
# ...

# %% [markdown]
# ##SKEWNESS

# %%
dataset["BMI"].skew()
# Out:
# 0.13580859812143145

# %%
dataset["BMI"].kurtosis()  #<3 Lesser than NormalDistribution
# Out:
# 0.05005285152648442

# %%
bmi_kurtosis = dataset['BMI'].kurtosis()
plt.figure(figsize=(6, 3))
plt.scatter('BMI', bmi_kurtosis, color='green')
plt.xlabel('Column')
plt.ylabel('Kurtosis Value')
plt.title('Kurtosis Chart for BMI Column')
plt.show()

# %% [markdown]
# ##8)Probability Distribution Function For the age between 25 to 30

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'yellow'},color='darkblue')
    pyplot.axvline(startrange,color='green')
    pyplot.axvline(endrange,color='green')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.2f, Standard Deviation=%.2f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset["Age"],25,30)
# Out:
# Mean=33.20, Standard Deviation=11.63
# The area between range(25,30):0.14802558587671658
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12680\827230667.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset,kde=True,kde_kws={'color':'yellow'},color='darkblue')
# 0.14802558587671658

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf = ECDF(dataset['Age'])
ecdf(20)
# Out:
# 0.0

# %% [markdown]
# ## BIVARIATE

# %% [markdown]
# ##9) Diabetes person display the tests of corelation and covariace

# %%
diabetes_dataset = dataset[dataset['Outcome'] == 1]

# %%
diabetes_dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0             72             35    0.000  33.6
# 2            8.0    183.0             64              0    0.000  23.3
# 4            0.0    137.0             40             35  168.000  43.1
# 6            3.0     78.0             50             32   88.000  31.0
# 8            2.0    197.0             70             45  318.125  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755          1.0    128.0             88             39  110.000  36.5
# 757          0.0    123.0             72              0    0.000  36.3
# 759          6.0    190.0             92              0    0.000  35.5
# 761          9.0    170.0             74             31    0.000  44.0
# 766          1.0    126.0             60              0    0.000  30.1
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0        1
# ...

# %%
diabetes_dataset.drop('Age',inplace=True,axis=1)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12680\891318984.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diabetes_dataset.drop('Age',inplace=True,axis=1)

# %%
diabetes_dataset.drop('Outcome',inplace=True,axis=1)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12680\784228852.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diabetes_dataset.drop('Outcome',inplace=True,axis=1)

# %% [markdown]
# ##10) pregnancy with diabetes patient show the relation and covariance of tests

# %%
##First drop the patient dont have pregnancy

# %%
to_drop=diabetes_dataset[diabetes_dataset['Pregnancies'] == 0].index
#zero pregnancies i deleted

# %%
diabetes_dataset = diabetes_dataset.drop(to_drop)

# %%
diabetes_dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0            6.0    148.0             72             35    0.000  33.60
# 2            8.0    183.0             64              0    0.000  23.30
# 6            3.0     78.0             50             32   88.000  31.00
# 8            2.0    197.0             70             45  318.125  30.50
# 9            8.0    125.0             96              0    0.000  13.35
# ..           ...      ...            ...            ...      ...    ...
# 754          8.0    154.0             78             32    0.000  32.40
# 755          1.0    128.0             88             39  110.000  36.50
# 759          6.0    190.0             92              0    0.000  35.50
# 761          9.0    170.0             74             31    0.000  44.00
# 766          1.0    126.0             60              0    0.000  30.10
#
#      DiabetesPedigreeFunction
# 0                       0.627
# 2                       0.672
# ...

# %%
diabetes_dataset.cov()
# Out:
#                           Pregnancies     Glucose  BloodPressure  \
# Pregnancies                 11.265350   -5.143692       5.399203
# Glucose                     -5.143692  977.939949      41.356071
# BloodPressure                5.399203   41.356071     199.144504
# SkinThickness               -3.892500    1.686202      28.496905
# Insulin                    -38.667296  848.782532      77.204227
# BMI                         -0.880957    2.344256      19.737531
# DiabetesPedigreeFunction    -0.009302   -0.372774       0.276310
#
#                           SkinThickness       Insulin        BMI  \
# Pregnancies                   -3.892500    -38.667296  -0.880957
# Glucose                        1.686202    848.782532   2.344256
# BloodPressure                 28.496905     77.204227  19.737531
# SkinThickness                296.909132   1049.827644  28.812313
# Insulin                     1049.827644  11906.969643  58.245457
# ...

# %%
##This positive value suggests that as the number of pregnancies increases, BloodPressure levels tend to increase as well
##This Negative value suggests that as the number of pregnancies increases insulin levels decreases

# %%
diabetes_dataset.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000 -0.049006       0.113992      -0.067305
# Glucose                     -0.049006  1.000000       0.093713       0.003129
# BloodPressure                0.113992  0.093713       1.000000       0.117193
# SkinThickness               -0.067305  0.003129       0.117193       1.000000
# Insulin                     -0.105577  0.248737       0.050137       0.558349
# BMI                         -0.041708  0.011912       0.222250       0.265705
# DiabetesPedigreeFunction    -0.008932 -0.038416       0.063100       0.268785
#
#                            Insulin       BMI  DiabetesPedigreeFunction
# Pregnancies              -0.105577 -0.041708                 -0.008932
# Glucose                   0.248737  0.011912                 -0.038416
# BloodPressure             0.050137  0.222250                  0.063100
# ...

# %%
##A Positive correlation insulin increases skin thickness Increases ( strength-0.5) low positive correlation
#0.1(MInimal Correlation)  0 (No relationship)

# %% [markdown]
# ##11) How much Fstatic variance between glucose,BP and Insulin of diabetes of pregnancy

# %%
import scipy.stats as stats

stats.f_oneway(diabetes_dataset['Glucose'],diabetes_dataset['BloodPressure'],diabetes_dataset['Insulin'])
# Out:
# F_onewayResult(statistic=64.71144462412917, pvalue=1.7855728034087677e-26)
